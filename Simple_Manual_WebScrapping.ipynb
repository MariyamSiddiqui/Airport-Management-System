# %% [markdown]
# <a href="https://colab.research.google.com/github/MariyamSiddiqui/Airport-Management-System/blob/main/Simple_Manual_WebScrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
netflix = pd.read_html('https://en.wikipedia.org/wiki/List_of_most-watched_Netflix_original_programming')

# %%
len(netflix)
# Out:
# 3

# %%
netflix[2]
# Out:
#                   vteNetflix  \
# 0  Operated by Netflix, Inc.
# 1                Programming
# 2                     Assets
# 3                    History
# 4                  Accolades
# 5                    Culture
# 6                     Others
#
#                                         vteNetflix.1
# 0                          Operated by Netflix, Inc.
# 1  Original programming Ended Original films Orig...
# 2  Albuquerque Studios Animal Logic Boss Fight En...
# 3  Timeline International expansion Red Envelope ...
# 4  BAFTA Awards Critics' Choice Television Awards...
# 5  Netflix and chill Netflix and LGBT representat...
# 6  Chaos engineering Conductor Netflix button Par...
